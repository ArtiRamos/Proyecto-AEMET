# %%
#PIPELINE DE EXTRACCIÓN DE PRIMER CSV

# %%
API_KEY = "eyJhbGciOiJIUzI1NiJ9.eyJzdWIiOiJhcnRpcmFtb3NAaG90bWFpbC5jb20iLCJqdGkiOiJhMjRhYTA0OS0xOTc0LTQxMGItOWQ0MC0xMGE1MDZmMTY3ZjUiLCJpc3MiOiJBRU1FVCIsImlhdCI6MTc3Mzk0NTE3OCwidXNlcklkIjoiYTI0YWEwNDktMTk3NC00MTBiLTlkNDAtMTBhNTA2ZjE2N2Y1Iiwicm9sZSI6IiJ9.oj-SE6UvLLFeQ4bs1B-I7FMsyARYnUvojwuISv-xWEQ"

# %%
import json
import pandas as pd
import requests

# %%
api_key = API_KEY

url = "https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/2025-11-01T00%3A00%3A00UTC/fechafin/2026-04-06T00%3A00%3A00UTC/estacion/3129"



params = {
    "api_key" : API_KEY}

response = requests.get(url, params=params)
response.raise_for_status()
data = response.json()
    

datos_url = data["datos"]
response_datos = requests.get(datos_url)
datos_finales = response_datos.json()

# %%
df = pd.DataFrame(datos_finales)
df
# Out:
#           fecha indicativo             nombre provincia altitud  tmed prec  \
# 0    2025-11-01       3129  MADRID AEROPUERTO    MADRID     609  15,4  0,0
# 1    2025-11-02       3129  MADRID AEROPUERTO    MADRID     609  13,2  0,0
# 2    2025-11-03       3129  MADRID AEROPUERTO    MADRID     609  11,9  0,0
# 3    2025-11-04       3129  MADRID AEROPUERTO    MADRID     609  11,9  0,0
# 4    2025-11-05       3129  MADRID AEROPUERTO    MADRID     609  13,5  0,9
# ..          ...        ...                ...       ...     ...   ...  ...
# 152  2026-04-02       3129  MADRID AEROPUERTO    MADRID     609  12,6  0,0
# 153  2026-04-03       3129  MADRID AEROPUERTO    MADRID     609  12,2  0,0
# 154  2026-04-04       3129  MADRID AEROPUERTO    MADRID     609  14,8  0,0
# 155  2026-04-05       3129  MADRID AEROPUERTO    MADRID     609  16,6  0,0
# 156  2026-04-06       3129  MADRID AEROPUERTO    MADRID     609  16,4  0,0
#
# ...

# %%
df.to_csv("aemet_aeropuerto.csv", index = False)
